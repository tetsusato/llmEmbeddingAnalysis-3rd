# %%
# %run visualize_vectors.py --mode original
# Out:
# len(vecs)= 100
# vecs= shape: (100, 2)
# ┌─────────────────────────────────┬─────────────────────────────────┐
# │ embedding1                      ┆ embedding2                      │
# │ ---                             ┆ ---                             │
# │ array[f64, 384]                 ┆ array[f64, 384]                 │
# ╞═════════════════════════════════╪═════════════════════════════════╡
# │ [0.065392, 0.02813, … 0.032704… ┆ [0.037159, 0.014117, … 0.06326… │
# │ [0.081221, -0.02136, … 0.06418… ┆ [0.043285, -0.041842, … 0.0431… │
# │ [0.017162, 0.024835, … -0.0025… ┆ [-0.038157, -0.033265, … -0.01… │
# │ [0.047791, -0.053223, … -0.017… ┆ [0.039619, -0.00094, … -0.0313… │
# │ [0.018254, 0.015902, … 0.04067… ┆ [0.020997, -0.002901, … 0.0527… │
# │ …                               ┆ …                               │
# │ [0.019819, 0.004342, … -0.0214… ┆ [0.012392, -0.091714, … 0.0635… │
# │ [-0.011899, -0.025993, … -0.02… ┆ [-0.00255, -0.026083, … -0.024… │
# ...

# %%
# %run visualize_vectors.py --mode finetuned
# Out:
# shape: (100, 5)
# ┌──────────────────────┬──────────────────────┬──────────────────────┬─────────────────────┬───────┐
# │ sentence1            ┆ embedding1           ┆ sentence2            ┆ embedding2          ┆ label │
# │ ---                  ┆ ---                  ┆ ---                  ┆ ---                 ┆ ---   │
# │ str                  ┆ array[f64, 384]      ┆ str                  ┆ array[f64, 384]     ┆ f64   │
# ╞══════════════════════╪══════════════════════╪══════════════════════╪═════════════════════╪═══════╡
# │ A plane is taking    ┆ [0.049173, 0.010323, ┆ An air plane is      ┆ [0.026446,          ┆ 5.0   │
# │ off.                 ┆ … 0.00821…           ┆ taking off.          ┆ 0.005033, …         ┆       │
# │                      ┆                      ┆                      ┆ 0.02430…            ┆       │
# │ A man is playing a   ┆ [0.082049, -0.02354, ┆ A man is playing a   ┆ [0.043244,          ┆ 3.8   │
# ...
