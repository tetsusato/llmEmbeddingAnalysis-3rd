# %% [markdown]
# - まずはFIT2024の再現か．頑張らないとそれだけで大変だ．

# %%
# %pwd
# Out:
# '/home/tetsu_sato1/llmEmbeddingAnalysis-3rd'

# %%
import importlib
import visualize_vectors
importlib.reload(visualize_vectors)
# %run reduce_vectors_test.py
# Out:
# 2024-07-04 05:46:58,287] MainProcess(2640883).MainThread(139705663784768) config.<module>(58) INFO -> PyTorch version 2.3.1 available.
# 2024-07-04 05:46:58,289] MainProcess(2640883).MainThread(139705663784768) config.<module>(70) INFO -> Polars version 0.20.31 available.
# __main__
# 2024-07-04 05:47:14,032] MainProcess(2640883).MainThread(139705663784768) SentenceTransformer.__init__(189) INFO -> Use pytorch device_name: cuda
# 2024-07-04 05:47:14,033] MainProcess(2640883).MainThread(139705663784768) SentenceTransformer.__init__(197) INFO -> Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# df=shape: (100, 5)
# ...

# %%
import importlib
import visualize_vectors
importlib.reload(visualize_vectors)
# %run reduce_vectors_test.py
# Out:
# __main__
# 2024-07-05 09:59:54,041] MainProcess(2640883).MainThread(139705663784768) reduce_vectors_test.<module>(407) INFO -> perplexity=1
# 2024-07-05 10:00:04,140] MainProcess(2640883).MainThread(139705663784768) SentenceTransformer.__init__(189) INFO -> Use pytorch device_name: cuda
# 2024-07-05 10:00:04,140] MainProcess(2640883).MainThread(139705663784768) SentenceTransformer.__init__(197) INFO -> Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loaded: shape: (1, 5)
# ┌───────────┬────────────┬───────────┬────────────┬───────┐
# │ sentence1 ┆ embedding1 ┆ sentence2 ┆ embedding2 ┆ label │
# │ ---       ┆ ---        ┆ ---       ┆ ---        ┆ ---   │
# ...

# %%
import importlib
import visualize_vectors
importlib.reload(visualize_vectors)
# %run reduce_vectors_test.py
# Out:
# __main__
# 2024-07-05 10:13:31,496] MainProcess(2640883).MainThread(139705663784768) SentenceTransformer.__init__(189) INFO -> Use pytorch device_name: cuda
# 2024-07-05 10:13:31,497] MainProcess(2640883).MainThread(139705663784768) SentenceTransformer.__init__(197) INFO -> Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loaded: shape: (1, 5)
# ┌───────────┬────────────┬───────────┬────────────┬───────┐
# │ sentence1 ┆ embedding1 ┆ sentence2 ┆ embedding2 ┆ label │
# │ ---       ┆ ---        ┆ ---       ┆ ---        ┆ ---   │
# │ u32       ┆ u32        ┆ u32       ┆ u32        ┆ u32   │
# ╞═══════════╪════════════╪═══════════╪════════════╪═══════╡
# ...

# %% [markdown]
# ### ここからoptuna導入 for TDA

# %%
import importlib
import reduce_vectors_test
importlib.reload(reduce_vectors_test)
# %run reduce_vectors_test.py TDA
# Out:
# [I 2024-07-06 18:33:38,625] Using an existing study with name 'tda' instead of creating a new one.
# 2024-07-06 18:33:38,720] MainProcess(2640883).MainThread(139705663784768) reduce_vectors_test.objective_tda(407) INFO -> delay=10, stride=10
# 2024-07-06 18:33:48,011] MainProcess(2640883).MainThread(139705663784768) SentenceTransformer.__init__(189) INFO -> Use pytorch device_name: cuda
# 2024-07-06 18:33:48,012] MainProcess(2640883).MainThread(139705663784768) SentenceTransformer.__init__(197) INFO -> Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ...

# %%
import importlib
import reduce_vectors_test
importlib.reload(reduce_vectors_test)
# %run reduce_vectors_test.py TSNE
# Out:
# [I 2024-07-06 18:39:23,870] Using an existing study with name 'tsne' instead of creating a new one.
# 2024-07-06 18:39:23,923] MainProcess(2640883).MainThread(139705663784768) reduce_vectors_test.objective_tsne(444) INFO -> perplexity=8
# 2024-07-06 18:39:33,002] MainProcess(2640883).MainThread(139705663784768) SentenceTransformer.__init__(189) INFO -> Use pytorch device_name: cuda
# 2024-07-06 18:39:33,003] MainProcess(2640883).MainThread(139705663784768) SentenceTransformer.__init__(197) INFO -> Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ...
